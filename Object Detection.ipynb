# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
results = model(r"C:\Users\Dell\Downloads\WhatsApp Image 2026-06-21 at 13.47.36.jpeg", save = True)
# Out:
# image 1/1 C:\Users\Dell\Downloads\WhatsApp Image 2026-06-21 at 13.47.36.jpeg: 640x384 4 persons, 1 cup, 4 potted plants, 2 tvs, 3 laptops, 131.4ms
# Speed: 5.2ms preprocess, 131.4ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to C:\Users\Dell\runs\detect\predict-3
